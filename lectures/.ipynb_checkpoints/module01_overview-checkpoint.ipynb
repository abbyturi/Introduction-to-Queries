# %% [markdown]
# # Module 1: Introduction to Relational Databases and SQL

# %% [markdown]
# ## Module 1 materials
#
# - [Lecture: Foundations of Data Management and Your First SQL Queries](lecture.qmd)
# - [Lab 1: PostgreSQL Environment and First Queries](lab01.qmd)

# %% [markdown]
# ## Focus
#
# - Relational databases and SQL
# - Structured, semi-structured, and unstructured data
# - Tables, rows, columns, primary keys, and foreign keys
# - PostgreSQL with Neon and DBeaver
# - Introductory queries with `SELECT`, `FROM`, `WHERE`, `ORDER BY`, and `LIMIT`
